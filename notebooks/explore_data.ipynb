# %% [markdown]
# # Исследовательский анализ данных (EDA)
#
# Описание задачи: "Пайплайн анализа данных для DS-проекта".
#
# *Данные пока отсутствуют — добавьте в `data/raw/`*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Настройки
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Загрузка данных (пример)
# df = pd.read_csv("../data/raw/sample.csv")
# print(df.info())
# print(df.head())

# TODO: Загрузите свои данные и начните EDA
